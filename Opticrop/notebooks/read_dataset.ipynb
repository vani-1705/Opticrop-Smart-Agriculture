# %% [markdown]
# #***Read the Dataset***
# This module loads the agricultural dataset into the notebook and performs an initial inspection to understand its structure, size, and data types before further processing.

# %% [markdown]
# #**1.Import Libraries**

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

plt.style.use('fivethirtyeight')
# %matplotlib inline

# %% [markdown]
# **Why:** Loads the core libraries required for data handling and visualization throughout the project.

# %% [markdown]
# #**2.Mount Drive & Load Dataset**

# %%
import pandas as pd
from google.colab import drive
drive.mount('/content/drive')

data = pd.read_csv('/content/drive/MyDrive/Crop_recommendation.csv')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %% [markdown]
# **Why:** Connects Google Drive to Colab and loads the CSV dataset into a DataFrame.

# %% [markdown]
# #**3.View First Few Records**

# %%
data.head()
# Out:
#     N   P   K  temperature   humidity        ph    rainfall label
# 0  90  42  43    20.879744  82.002744  6.502985  202.935536  rice
# 1  85  58  41    21.770462  80.319644  7.038096  226.655537  rice
# 2  60  55  44    23.004459  82.320763  7.840207  263.964248  rice
# 3  74  35  40    26.491096  80.158363  6.980401  242.864034  rice
# 4  78  42  42    20.130175  81.604873  7.628473  262.717340  rice

# %% [markdown]
# **Why:** Displays the first 5 rows to verify the dataset loaded correctly and check column names.

# %% [markdown]
# #**4.Check Dataset Shape**

# %%
data.shape
# Out:
# (2200, 8)

# %% [markdown]
# **Why:** Shows the total number of rows and columns in the dataset.

# %% [markdown]
# #**5.Check Dataset Info**

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2200 entries, 0 to 2199
# Data columns (total 8 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   N            2200 non-null   int64
#  1   P            2200 non-null   int64
#  2   K            2200 non-null   int64
#  3   temperature  2200 non-null   float64
#  4   humidity     2200 non-null   float64
#  5   ph           2200 non-null   float64
#  6   rainfall     2200 non-null   float64
#  7   label        2200 non-null   object
# dtypes: float64(4), int64(3), object(1)
# memory usage: 137.6+ KB

# %% [markdown]
# **Why:** Displays column names,data types, and non-null counts for each feature.

# %% [markdown]
# ###**Conclusion:**
# The dataset  was successfully loaded with 2200 records and 8 columns,all properly structured and ready for further preprocessing steps.
#
# This module was completed by **Vani Vasantha Laxmi Yepparika** as part of the Data Preprocessing phase of the Opticrop Project, focused on reading and inspecting the dataset.
